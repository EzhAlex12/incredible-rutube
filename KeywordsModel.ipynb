# %%
# !pip install transformers
# !pip install sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 38.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 26.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 75.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.2 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
text = '''The main channel about hockey! Here, the top guests talk about hockey in such a way that even those who can't see it in the broadcast can understand it. With us, Denise Kazansky comments on hockey, plays hockey, and loves to talk about hockey. Andrei Nikolishin is a player, a coach, a scout, an expert on all kinds of flounder disputes. Sergei Guimaev is a KHL player who has become a brilliant expert. Bright emotional panchies and a cold-blooded analyst. Maxim Goncharov and Alexey Potapov are active players who make the most forthright podcast about a favorite game. News, rumors, humor, live broadcasts and reviews of the coolest that happens on and outside the ice. Sign!'''
pipe = pipeline("summarization", model="transformer3/H2-keywordextractor")

# %%
pipe(text)[0]['summary_text'].split(',  ')
# Out:
# ['Hockey',
#  'Denise Kazansky',
#  'Andrei Nikolishin',
#  'Sergei Guimaev',
#  'Maxim Goncharov',
#  'Alexey Potapov']
